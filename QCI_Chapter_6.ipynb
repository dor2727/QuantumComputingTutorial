# %%
import sys
print(sys.version)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg' # Makes the images look nice

from qiskit import(
  QuantumCircuit,
  QuantumRegister, ClassicalRegister,
  execute,
  Aer)
from qiskit.visualization import plot_histogram
# Out:
# 3.8.1 (tags/v3.8.1:1b293b6006, Jan  6 2020, 11:40:25)
# [GCC 9.2.1 20191008]

# %%
# measurement along the Z axis (1 qbit)

c = QuantumCircuit(1, 1)
c.measure(0, 0)
c.draw(output="mpl")

# %%
# measurement along the X axis (1 qbit)

c = QuantumCircuit(1, 1)
c.h(0)
c.measure(0, 0)
c.draw(output="mpl")

# %%
# measurement along the Z axis (2 qbits)

c = QuantumCircuit(2, 2)
c.measure([0,1], [0,1])
c.draw(output="mpl")

# %%
# measurement along the X axis (2 qbits)

c = QuantumCircuit(2, 2)
c.h(0)
c.h(1)
c.measure([0,1], [0,1])
c.draw(output="mpl")

# %%
# measurement along the Z & X axis (2 qbits)

c = QuantumCircuit(2, 2)
c.h(1)
c.measure([0,1], [0,1])
c.draw(output="mpl")

# %%
# measurement along the Z axis (1 out of 2 qbits)

c = QuantumCircuit(2, 2)
c.measure(0, 0)
c.draw(output="mpl")

# %%
# measurement along the Z axis (1 out of 2 qbits)

c = QuantumCircuit(2, 2)
c.h(1)
c.cx(1, 0)
c.draw(output="mpl")

# %%
# measurement along the Z axis (1 out of 2 qbits)

c = QuantumCircuit(2, 2)
c.cx(1, 0)
c.h(1)
c.measure([0,1], [0,1])
c.draw(output="mpl")
